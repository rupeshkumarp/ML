# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
data={'area':[2600,3000,3200,3600,4000],
      'price':[550000,565000,610000,680000,725000]}

# %%
df=pd.DataFrame(data)

# %%
plt.scatter(df.area,df.price,color='red',marker='*',s=100)
plt.xlabel('Area in sq ft') 
plt.ylabel('Price in US$')
plt.grid()
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3400]]).round(2)
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([642294.52])

# %%
reg.coef_ #slope w
# Out:
# array([135.78767123])

# %%
reg.intercept_ #y-intercept b
# Out:
# np.float64(180616.43835616432)

# %%
#y =w*x + b
135.78767123*3400+180616.43835616432
# Out:
# 642294.5205381643

# %%
reg.predict([[5000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
area=[1000,1500,2000,2500,3000,3500,4000,4500,5000,5500,6000]
d=pd.DataFrame(area,columns=['area'])

# %%
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2000
# 3  2500
# 4  3000

# %%
price=reg.predict(d)

# %%
price
# Out:
# array([316404.10958904, 384297.94520548, 452191.78082192, 520085.61643836,
#        587979.45205479, 655873.28767123, 723767.12328767, 791660.95890411,
#        859554.79452055, 927448.63013699, 995342.46575342])

# %%
d['prince']=price

# %%
d.head()
# Out:
#    area         prince
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2000  452191.780822
# 3  2500  520085.616438
# 4  3000  587979.452055

# %%
plt.plot(d.area,d.prince,marker='*',color='red',linestyle='--',markersize=10,label='Predicted Price')
plt.xlabel('Area in sq ft') 
plt.ylabel('Price in US$')
plt.grid()
plt.show()

# %%
reg.predict([[6000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([995342.46575342])

# %%
# d.to_csv('predicted_price.csv',index=False) TO SAVE THE FILE

# %%
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
plt.grid()
plt.show()

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg.coef_  #slope w
# Out:
# array([828.46507522])

# %%
reg.intercept_  #y-intercept b
# Out:
# np.float64(-1632210.7578554575)

# %%
reg.predict([[2020]])
#y =w*x + b
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='*')
plt.plot(df.year,reg.predict(df[['year']]),color='blue')
plt.grid()
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.show()

# %% [markdown]
# <h1>Linear regression with multivareant </h1>

# %%
area=[2600,3000,3200,3600,4000]
bedrooms=[3,4,3,3,4]
price=[550000,565000,610000,680000,725000]

# %%
lr=pd.DataFrame({'area':area,'bedrooms':bedrooms,'price':price})

# %%
lr
# Out:
#    area  bedrooms   price
# 0  2600         3  550000
# 1  3000         4  565000
# 2  3200         3  610000
# 3  3600         3  680000
# 4  4000         4  725000

# %%
lr['age']=[20,15,18,30,8]

# %%
reg=linear_model.LinearRegression()
reg.fit(lr[['area','bedrooms','age']],lr.price)
# Out:
# LinearRegression()

# %%
reg.coef_  #coefficients
# Out:
# array([   144.04880789, -24852.07839221,   -331.41929846])

# %%
reg.intercept_  #y-intercept b
# Out:
# np.float64(244048.80788915238)

# %%
(144.04880789*3000)+(-24852.07839221*3)+(-331.41929846*40)+244048.80788915238
# Out:
# 588382.2244441225

# %%
reg.predict([[3000,3,40]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([588382.22444139])

# %%
reg.predict([[2500,4,5]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([503105.41755087])

# %%
plt.scatter(lr.area,lr.price,color='red',marker='*')
plt.plot(lr.area,reg.predict(lr[['area','bedrooms','age']]),color='blue')

# %% [markdown]
# <h1>pratices model</h1>

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\hiring.csv")

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
mapping={'zero':0,'one':1,'two':2,'three':3,'four':4,'five':5,'seven':7,'eight':8,'nine':9,'ten':10,'eleven':11,'twelve':12}
df['experience'] = df['experience'].map(mapping)

# %%
df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].median(),inplace=True)
# Out:
# C:\Users\Jeevan kumar\AppData\Local\Temp\ipykernel_22008\55181911.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].median(),inplace=True)

# %%
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0         NaN                    8.0                           9      50000
# 1         NaN                    8.0                           6      45000
# 2         5.0                    6.0                           7      60000
# 3         2.0                   10.0                          10      65000
# 4         7.0                    9.0                           6      70000
# 5         3.0                    7.0                          10      62000
# 6        10.0                    8.0                           7      72000
# 7        11.0                    7.0                           8      80000

# %%
df['experience'].fillna(method='bfill',inplace=True)
# Out:
# C:\Users\Jeevan kumar\AppData\Local\Temp\ipykernel_22008\3876311365.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['experience'].fillna(method='bfill',inplace=True)
# C:\Users\Jeevan kumar\AppData\Local\Temp\ipykernel_22008\3876311365.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['experience'].fillna(method='bfill',inplace=True)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['experience','test_score(out of 10)','interview_score(out of 10)']],df['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45979.08171436])

# %%
reg.predict([[12,10,10]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92515.82422727])

# %%
plt.scatter(df['experience'],df['salary($)'],color='red',marker='*')
plt.plot(df['experience'],reg.predict(df[['experience','test_score(out of 10)','interview_score(out of 10)']]),color='red')

# %%
plt.scatter(df['test_score(out of 10)'],df['salary($)'],color='blue',marker='o')
plt.plot(df['test_score(out of 10)'],reg.predict(df[['experience','test_score(out of 10)','interview_score(out of 10)']]),color='blue')

# %%
plt.scatter(df['interview_score(out of 10)'],df['salary($)'],color='green',marker='^')
plt.plot(df['interview_score(out of 10)'],reg.predict(df[['experience','test_score(out of 10)','interview_score(out of 10)']]),color='green')

# %% [markdown]
# <h1>Gradient desecent</h1>

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=10000
    n=len(x)
    learning_rate=0.08

    for i in range(iterations):
        y_predicted=m_curr*x+b_curr
        cost=(1/n)*sum([val **2 for val in (y - y_predicted)])
        bd=-(2/n)*sum((y - y_predicted))
        md=-(2/n)*sum(x*(y - y_predicted))
        m_curr=m_curr - learning_rate*md
        b_curr=b_curr - learning_rate*bd

        print( f"m {m_curr}, b {b_curr}, cost {cost}, iteration {i}" )

# %%
gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0, iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002, iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001, iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613, iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832, iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282, iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438, iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738, iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156, iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794, iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109, iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315, iteration 11
# ...
