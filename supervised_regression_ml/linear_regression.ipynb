# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# formula:
# y=m*x+b

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\ML_Regression_LinearRegression_resources\home_prices.csv")
df.head()
# Out:
#    area_sqr_ft  price_lakhs
# 0          656         39.0
# 1         1260         83.2
# 2         1057         86.6
# 3         1259         59.0
# 4         1800        140.0

# %%
df.dtypes
# Out:
# area_sqr_ft      int64
# price_lakhs    float64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(df[['area_sqr_ft']],df.price_lakhs)
# Out:
# LinearRegression()

# %%
scope=model.coef_

# %%
model.predict([[2000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([121.41001208])

# %%
inter=model.intercept_

# %%
(scope*2000)+inter
# Out:
# array([121.41001208])

# %%
model.score(df[['area_sqr_ft']],df.price_lakhs)
# Out:
# 0.4435533157481356

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(df[['area_sqr_ft']],df.price_lakhs,test_size=0.2)

# %%
model_score=model.score(x_test,y_test)
model_score
# Out:
# 0.6239467291850554

# %%
std,mean=df.price_lakhs.std(),df.price_lakhs.mean()
std,mean
# Out:
# (np.float64(29.870948438341564), np.float64(81.40833333333335))

# %%
plt.scatter(df.area_sqr_ft,df.price_lakhs)
plt.plot(df.area_sqr_ft,model.predict(df[['area_sqr_ft']]),color='b')

# %%
plt.boxplot(df.price_lakhs)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e0907eb890>,
#   <matplotlib.lines.Line2D at 0x1e0907eb9d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e0907ebb10>,
#   <matplotlib.lines.Line2D at 0x1e0907ebc50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e0907eb750>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e0907ebd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e0907ebed0>],
#  'means': []}

# %%
df['z_score']=(df.price_lakhs-mean)/std

# %%
df[df['z_score']>2]
# Out:
#    area_sqr_ft  price_lakhs   z_score
# 4         1800        140.0  1.961493
# 6         1085        116.0  1.158037

# %% [markdown]
# <h1>multiple linear regression</h1>
# formula= m1*x1+m2*x3+.....b

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\ML_Regression_MultipleLinearRegression_resources\home_prices.csv")
df.head()
# Out:
#    area_sqr_ft  price_lakhs  bedrooms
# 0          656         39.0         2
# 1         1260         83.2         2
# 2         1057         86.6         3
# 3         1259         59.0         2
# 4         1800        140.0         3

# %%
linear_model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['area_sqr_ft','bedrooms']],df.price_lakhs,test_size=0.2)

# %%
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.03728636964175025

# %%
linear_model.predict([[1500,2]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73.81647119])

# %%
test=pd.DataFrame({'area_sqr_ft':[1500,2000],'bedrooms':[2,3]})
linear_model.predict(test)
# Out:
# array([ 73.81647119, 126.90166134])

# %%
s,intercept=linear_model.coef_,linear_model.intercept_
s,intercept
# Out:
# (array([3.32181778e-02, 3.64761013e+01]), np.float64(-48.96299798950676))

# %%
linear_model.coef_[0]*1500+linear_model.coef_[1]*2+linear_model.intercept_
# Out:
# np.float64(73.816471191987)
