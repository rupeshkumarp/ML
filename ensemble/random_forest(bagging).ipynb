# %%
import pandas as pd

df=pd.read_excel('data/Raisin_Dataset.xlsx')
df.sample(5)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 149   66568       342.250361       249.550500      0.684358       68078
# 427   39622       280.112477       185.192206      0.750267       40539
# 362   64669       364.582804       228.800767      0.778561       67524
# 96    79661       360.073447       282.739032      0.619209       81032
# 759  132116       519.679984       325.332488      0.779803      133811
#
#        Extent  Perimeter    Class
# 149  0.759917    993.455  Kecimen
# 427  0.733008    766.531  Kecimen
# 362  0.655846    995.692  Kecimen
# 96   0.779157   1045.658  Kecimen
# 759  0.745071   1393.335    Besni

# %%
df.columns
# Out:
# Index(['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
#        'ConvexArea', 'Extent', 'Perimeter', 'Class'],
#       dtype='str')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0    87524       442.246011       253.291155      0.819738       90546
# 1    75166       406.690687       243.032436      0.801805       78789
# 2    90856       442.267048       266.328318      0.798354       93717
# 3    45928       286.540559       208.760042      0.684989       47336
# 4    79408       352.190770       290.827533      0.564011       81463
# ..     ...              ...              ...           ...         ...
# 895  83248       430.077308       247.838695      0.817263       85839
# 896  87350       440.735698       259.293149      0.808629       90899
# 897  99657       431.706981       298.837323      0.721684      106264
# 898  93523       476.344094       254.176054      0.845739       97653
# 899  85609       512.081774       215.271976      0.907345       89197
#
#        Extent  Perimeter    Class
# 0    0.758651   1184.040  Kecimen
# 1    0.684130   1121.786  Kecimen
# 2    0.637613   1208.575  Kecimen
# 3    0.699599    844.162  Kecimen
# 4    0.792772   1073.251  Kecimen
# ..        ...        ...      ...
# 895  0.668793   1129.072    Besni
# 896  0.636476   1214.252    Besni
# 897  0.741099   1292.828    Besni
# 898  0.658798   1258.548    Besni
# 899  0.632020   1272.862    Besni
#
# [900 rows x 8 columns]>

# %% [markdown]
# # Model training

# %%
x = df.drop("Class", axis=1)
y = df["Class"]

# %% [markdown]
# ## decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

model=DecisionTreeClassifier()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.78      0.79      0.79        86
#      Kecimen       0.81      0.80      0.80        94
#
#     accuracy                           0.79       180
#    macro avg       0.79      0.79      0.79       180
# weighted avg       0.79      0.79      0.79       180

# %%
cm=confusion_matrix(y_test,y_pred)

import seaborn as sns
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ## Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(
    n_estimators=20,# Number of decision trees
    criterion='gini',# Function used to measure split quality
    max_depth=10,# Maximum depth of each tree
    min_samples_split=2,# Minimum samples required to split a node
    min_samples_leaf=1,# Minimum samples required in a leaf
    max_features='sqrt',# Number of features considered for each split
    bootstrap=True,# Use bootstrap samples
    class_weight=None,# Weight given to each class
    n_jobs=-1,# Use all available CPU cores
    random_state=42# Makes results reproducible
)
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.85      0.81      0.83        86
#      Kecimen       0.84      0.87      0.85        94
#
#     accuracy                           0.84       180
#    macro avg       0.85      0.84      0.84       180
# weighted avg       0.84      0.84      0.84       180

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt='d',cmap='Blues')
# Out:
# <Axes: >
