# %%
import numpy as np

# %%
v1=np.array([1, 2, 3])
v2=np.array([4, 5, 6])
print(v1+v2)
print(v1-v2)
print(v1*2)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [2 4 6]

# %%
np.dot(v1, v2)
# Out:
# np.int64(32)

# %%
np.linalg.norm(v1)
# Out:
# np.float64(3.7416573867739413)
