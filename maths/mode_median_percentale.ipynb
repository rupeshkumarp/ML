# %%
import pandas as pd
import numpy as np

# %%
name=["Jeevan","Kumar","Reddy",'ram','krishna','sai','ravi']
income=[5000,6000,4000,75000,8000,7000,10000000]

# %%
df=pd.DataFrame({"name":name,"income":income})

# %%
df
# Out:
#       name    income
# 0   Jeevan      5000
# 1    Kumar      6000
# 2    Reddy      4000
# 3      ram     75000
# 4  krishna      8000
# 5      sai      7000
# 6     ravi  10000000

# %%
df.describe()
# Out:
#              income
# count  7.000000e+00
# mean   1.443571e+06
# std    3.773118e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    4.150000e+04
# max    1.000000e+07

# %%
df.income.quantile(0.25)
# Out:
# np.float64(5500.0)

# %%
df.drop([df.income.idxmax()]) #inplace =True
# Out:
#       name  income
# 0   Jeevan    5000
# 1    Kumar    6000
# 2    Reddy    4000
# 3      ram   75000
# 4  krishna    8000
# 5      sai    7000

# %%
perc_99=df.income.quantile(0.99)
perc_99
# Out:
# np.float64(9404499.999999994)

# %%
df1=df[df.income<perc_99]

# %%
df1
# Out:
#       name  income
# 0   Jeevan    5000
# 1    Kumar    6000
# 2    Reddy    4000
# 3      ram   75000
# 4  krishna    8000
# 5      sai    7000

# %%
df['income'][3]=np.nan
# Out:
# C:\Users\Jeevan kumar\AppData\Local\Temp\ipykernel_7712\385840147.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['income'][3]=np.nan
# ...

# %%
df
# Out:
#       name      income
# 0   Jeevan      5000.0
# 1    Kumar      6000.0
# 2    Reddy      4000.0
# 3      ram         NaN
# 4  krishna      8000.0
# 5      sai      7000.0
# 6     ravi  10000000.0

# %%
df_new=df.fillna(df.income.mean())
df_new
# Out:
#       name        income
# 0   Jeevan  5.000000e+03
# 1    Kumar  6.000000e+03
# 2    Reddy  4.000000e+03
# 3      ram  1.671667e+06
# 4  krishna  8.000000e+03
# 5      sai  7.000000e+03
# 6     ravi  1.000000e+07

# %%
df_new=df.fillna(df.income.median())
df_new
# Out:
#       name      income
# 0   Jeevan      5000.0
# 1    Kumar      6000.0
# 2    Reddy      4000.0
# 3      ram      6500.0
# 4  krishna      8000.0
# 5      sai      7000.0
# 6     ravi  10000000.0

# %%
df_a=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\AB_NYC_2019.csv\AB_NYC_2019.csv")

# %%
df_a
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df_a.availability_365.describe()
# Out:
# count    48895.000000
# mean       112.781327
# std        131.622289
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        227.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
df_a.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df_a.availability_365.quantile(0.25,interpolation='lower')
# Out:
# np.int64(0)

# %%
df_a.price.quantile(0.99,interpolation='higher')
# Out:
# np.int64(799)

# %%
min_p,max_p=df_a.price.quantile([0.01,0.999])
min_p,max_p
# Out:
# (30.0, 3000.0)

# %%
df_a[df_a.price<min_p]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df_a[df_a.price>max_p].neighbourhood.value_counts()
# Out:
# neighbourhood
# Upper West Side       6
# Bedford-Stuyvesant    3
# Clinton Hill          3
# Upper East Side       3
# Greenwich Village     3
# Chelsea               3
# Lower East Side       2
# East Village          2
# Battery Park City     2
# Tribeca               2
# Harlem                2
# Astoria               1
# Little Italy          1
# Prospect Heights      1
# East Harlem           1
# Nolita                1
# West Village          1
# Randall Manor         1
# Cypress Hills         1
# Greenpoint            1
# Hell's Kitchen        1
# Midtown               1
# East Flatbush         1
# Bay Ridge             1
# Williamsburg          1
# Name: count, dtype: int64

# %%
df2=df_a[(df_a.price>min_p) & (df_a.price<max_p)]
df2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
np.std(df2.price)
# Out:
# np.float64(153.59320084403564)

# %%
df2['price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
