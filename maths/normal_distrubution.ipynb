# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\heights.csv")
df.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
df.describe()
# Out:
#              height
# count  10000.000000
# mean      66.367560
# std        3.847528
# min       54.263133
# 25%       63.505620
# 50%       66.318070
# 75%       69.174262
# max       78.998742

# %%
df['height'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.histplot(df['height'], kde=True)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
mean=df['height'].mean()
std=df['height'].std()
print(mean,std)
# Out:
# 66.367559754866 3.847528120795573

# %%
mean-3*std
# Out:
# np.float64(54.824975392479274)

# %%
mean+3*std
# Out:
# np.float64(77.91014411725271)

# %%
df[df['height']<mean-3*std]
# Out:
#       gender     height
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df[df['height']>mean+3*std]
# Out:
#      gender     height
# 994    Male  78.095867
# 1317   Male  78.462053
# 2014   Male  78.998742
# 3285   Male  78.528210
# 3757   Male  78.621374

# %%
df1=df[(df['height']<77.9) & (df['height']>54.82)]

# %%
df1
# Out:
#       gender     height
# 0       Male  73.847017
# 1       Male  68.781904
# 2       Male  74.110105
# 3       Male  71.730978
# 4       Male  69.881796
# ...      ...        ...
# 9995  Female  66.172652
# 9996  Female  67.067155
# 9997  Female  63.867992
# 9998  Female  69.034243
# 9999  Female  61.944246
#
# [9993 rows x 2 columns]

# %%
df.shape
# Out:
# (10000, 2)

# %%
df1.shape
# Out:
# (9993, 2)

# %%
df1['z_score']=(df1['height']-df1['height'].mean())/df1['height'].std()
# Out:
# C:\Users\Jeevan kumar\AppData\Local\Temp\ipykernel_26412\1987170247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['z_score']=(df1['height']-df1['height'].mean())/df1['height'].std()

# %%
df1.sample(5)
# Out:
#       gender     height   z_score
# 383     Male  70.961971  1.198827
# 6523  Female  67.031217  0.173995
# 7074  Female  68.710845  0.611910
# 1918    Male  69.324858  0.771997
# 890     Male  68.929672  0.668963

# %%
df1[df1['z_score']>3]
# Out:
# Empty DataFrame
# Columns: [gender, height, z_score]
# Index: []

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\bhp.csv")
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.price.describe()
# Out:
# count    13200.000000
# mean       112.276178
# std        149.175995
# min          8.000000
# 25%         50.000000
# 50%         71.850000
# 75%        120.000000
# max       3600.000000
# Name: price, dtype: float64

# %%
min_p,max_p=df.price.quantile([0.001,0.999])
min_p,max_p
# Out:
# (11.5, 2000.0)

# %%
df[df.price<min_p]
# Out:
#                  location       size  total_sqft  bath  price  bhk  \
# 169              Attibele      1 BHK       450.0   1.0  11.00    1
# 928              Attibele      1 BHK       400.0   1.0  11.00    1
# 1452              Kengeri      1 BHK       340.0   1.0  10.00    1
# 2408             Attibele      1 BHK       395.0   1.0  10.25    1
# 5360             Attibele      1 BHK       400.0   1.0  10.00    1
# 7403                other      1 BHK       470.0   2.0  10.00    1
# 8501           Chandapura      1 BHK       450.0   1.0   9.00    1
# 8560        Doddaballapur  2 Bedroom       640.0   1.0  10.50    2
# 10422  Yelahanka New Town      1 BHK       284.0   1.0   8.00    1
# 10983            Attibele      1 BHK       410.0   1.0  10.00    1
# 11832            Attibele      1 BHK       400.0   1.0  10.25    1
# 12463          Chandapura      1 BHK       410.0   1.0  10.00    1
#
#        price_per_sqft
# 169              2444
# 928              2750
# 1452             2941
# ...

# %%
df[df.price>max_p]
# Out:
#            location        size  total_sqft  bath   price  bhk  price_per_sqft
# 404    Rajaji Nagar       7 BHK     12000.0   6.0  2200.0    7           18333
# 598    Malleshwaram       7 BHK     12000.0   7.0  2200.0    7           18333
# 2592          other   4 Bedroom     30000.0   4.0  2100.0    4            7000
# 3144          other       5 BHK      8321.0   5.0  2700.0    5           32448
# 4119          other   4 Bedroom      7000.0   5.0  2050.0    4           29285
# 6356   Bommenahalli   4 Bedroom      2940.0   3.0  2250.0    4           76530
# 10203         other   4 Bedroom     10624.0   4.0  2340.0    4           22025
# 10972         other       4 BHK      8321.0   5.0  2912.0    4           34995
# 11650         other   5 Bedroom      9600.0   7.0  2736.0    5           28500
# 12328         other   4 Bedroom      4350.0   8.0  2600.0    4           59770
# 12948         other  10 Bedroom      7150.0  13.0  3600.0   10           50349
# ...

# %%
df[(df.price<min_p) | (df.price>max_p)]
# Out:
#                  location        size  total_sqft  bath    price  bhk  \
# 169              Attibele       1 BHK       450.0   1.0    11.00    1
# 404          Rajaji Nagar       7 BHK     12000.0   6.0  2200.00    7
# 598          Malleshwaram       7 BHK     12000.0   7.0  2200.00    7
# 928              Attibele       1 BHK       400.0   1.0    11.00    1
# 1452              Kengeri       1 BHK       340.0   1.0    10.00    1
# 2408             Attibele       1 BHK       395.0   1.0    10.25    1
# 2592                other   4 Bedroom     30000.0   4.0  2100.00    4
# 3144                other       5 BHK      8321.0   5.0  2700.00    5
# 4119                other   4 Bedroom      7000.0   5.0  2050.00    4
# 5360             Attibele       1 BHK       400.0   1.0    10.00    1
# 6356         Bommenahalli   4 Bedroom      2940.0   3.0  2250.00    4
# 7403                other       1 BHK       470.0   2.0    10.00    1
# ...

# %%
df1=df[(df.price>min_p) & (df.price<max_p)]

# %%
df1.shape
# Out:
# (13169, 7)

# %%
df1.price.describe()
# Out:
# count    13169.000000
# mean       109.711561
# std        125.440883
# min         11.660000
# 25%         50.000000
# 50%         71.890000
# 75%        120.000000
# max       1950.000000
# Name: price, dtype: float64

# %%
df.price.mean()
# Out:
# np.float64(112.27617765151514)

# %%
df.price.std()
# Out:
# np.float64(149.17599517809637)

# %%
max=df.price_per_sqft.mean() + 4*df.price_per_sqft.std()
min=df.price_per_sqft.mean() - 4*df.price_per_sqft.std()
print(min,max)
# Out:
# -418988.30457001046 434828.9780548589

# %%
df[(df.price<min) & (df.price>max)]
# Out:
# Empty DataFrame
# Columns: [location, size, total_sqft, bath, price, bhk, price_per_sqft]
# Index: []

# %%
df['z_score']=(df['price']-df['price'].mean())/df['price'].std()

# %%
df2.price.mean()
# Out:
# np.float64(112.27617765151514)

# %%
(3600-112.3)/df2.price.std()
# Out:
# np.float64(23.379766937945668)

# %%
df2=df[(df.price>min)&(df.price<max)]
df2
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft   z_score
# 0                3699 -0.490737
# ...

# %%
df2.price.describe()
# Out:
# count    13200.000000
# mean       112.276178
# std        149.175995
# min          8.000000
# 25%         50.000000
# 50%         71.850000
# 75%        120.000000
# max       3600.000000
# Name: price, dtype: float64

# %%
df2[(df2.z_score < -4) | (df2.z_score>4)]
# Out:
#                  location        size  total_sqft  bath   price  bhk  \
# 157    Mahalakshmi Layout   4 Bedroom     3750.00   4.0   760.0    4
# 404          Rajaji Nagar       7 BHK    12000.00   6.0  2200.0    7
# 598          Malleshwaram       7 BHK    12000.00   7.0  2200.0    7
# 733       Cunningham Road       4 BHK     5270.00   4.0  1250.0    4
# 1029                other   6 Bedroom     3968.00   5.0   900.0    6
# ...                   ...         ...         ...   ...     ...  ...
# 12868               other   6 Bedroom    30400.00   4.0  1824.0    6
# 12948               other  10 Bedroom     7150.00  13.0  3600.0   10
# 12967               other       5 BHK     5665.84   7.0   988.0    5
# 13078               other   4 Bedroom     9200.00   4.0  2600.0    4
# 13081               other   6 Bedroom     8000.00   6.0  2800.0    6
#
#        price_per_sqft    z_score
# 157             20266   4.342011
# 404             18333  13.995039
# 598             18333  13.995039
# ...

# %%
dfz = df[(df.z_score>-4)&(df.z_score<4)]

# %%
dfz.price.describe()
# Out:
# count    13093.000000
# mean       102.986217
# std         93.685881
# min          8.000000
# 25%         50.000000
# 50%         70.500000
# 75%        119.000000
# max        700.000000
# Name: price, dtype: float64

# %%
df.price.describe()
# Out:
# count    13200.000000
# mean       112.276178
# std        149.175995
# min          8.000000
# 25%         50.000000
# 50%         71.850000
# 75%        120.000000
# max       3600.000000
# Name: price, dtype: float64

# %%
df.shape
# Out:
# (13200, 8)

# %%
df1.shape
# Out:
# (13169, 7)

# %%
dfz.shape
# Out:
# (13093, 8)

# %%
sns.histplot(dfz['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df1['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
import numpy as np

# %%
np.log10(dfz.price).hist(bins=30, edgecolor='black', grid=True)
# Out:
# <Axes: >

# %%
sns.histplot(np.log10(dfz['price']), kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>
