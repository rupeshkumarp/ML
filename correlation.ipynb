# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'squ_ft': [1760, 1943, 1914, 1618, 1369],
    'price': [2.64, 2.98, 3.13, 1.76, 1.99]
})

# %%
df
# Out:
#    squ_ft  price
# 0    1760   2.64
# 1    1943   2.98
# 2    1914   3.13
# 3    1618   1.76
# 4    1369   1.99

# %%
df.plot(kind='scatter',y='price',x='squ_ft',figsize=(5,5))
# Out:
# <Axes: xlabel='squ_ft', ylabel='price'>

# %%
df['squ_ft'].corr(df['price'])
# Out:
# np.float64(0.8600379398337807)
