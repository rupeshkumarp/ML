# %%
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data={'area':[2600,3000,3200,3600,4000],
      'price':[550000,565000,610000,680000,725000]}
df=pd.DataFrame(data)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[5000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
plt.scatter(df.area,df.price,color='red',marker='*',s=100)
plt.plot(df.area,reg.predict(df[['area']]),color='blue',linestyle='dotted')

# %%
with open('model_pickle','wb') as f:
    pkl.dump(mp,f)

# %%
with open('model_pickle','rb') as f:
    mp=pkl.load(f)

# %%
mp.predict([[5000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([787336.15221987])

# %%
# df3=pd.concat([df,df2],ignore_index=True)

# %%
# from sklearn.externals import joblib
# joblib.dump(reg,'model_joblib') STORING MODEL USING JOBLIB
# mj=joblib.load('model_joblib') LOADING MODEL USING JOBLIB

# %%
mp.predict([[5000]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([787336.15221987])
